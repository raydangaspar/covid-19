# %% [markdown]
# <a href="https://colab.research.google.com/github/raydangaspar/covid-19/blob/master/SEIR_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SEIR Model to study Covid-19 propagation

# %%
import numpy as np
import matplotlib.pyplot as plt
